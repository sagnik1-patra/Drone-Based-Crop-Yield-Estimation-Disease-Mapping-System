# %%
import os
import json
import yaml
import joblib
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, LSTM, Conv1D, Flatten, Dropout, concatenate
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam

# ==============================================================
# 📂 PATH CONFIGURATION
# ==============================================================
base_path = r"C:\Users\NXTWAVE\Downloads\Drone Based Crop Yield Estimation & Disease Mapping System"
dataset_path = os.path.join(base_path, "archive", "Crop Yiled with Soil and Weather.csv")

# Output files (hybrid prefix)
model_path = os.path.join(base_path, "hybrid_skyharvest_model.h5")
scaler_path = os.path.join(base_path, "hybrid_skyharvest_scaler.pkl")
yaml_path = os.path.join(base_path, "hybrid_skyharvest_config.yaml")
json_path = os.path.join(base_path, "hybrid_skyharvest_prediction.json")
csv_path = os.path.join(base_path, "hybrid_skyharvest_result.csv")

# ==============================================================
# 🧠 STEP 1 — LOAD DATASET
# ==============================================================
print("\n[INFO] Loading dataset...")
df = pd.read_csv(dataset_path)
df = df.dropna()
print(f"[INFO] Dataset loaded: {df.shape[0]} rows, {df.shape[1]} columns")

# Assume last column is target (Yield)
X = df.iloc[:, :-1].values
y = df.iloc[:, -1].values

# ==============================================================
# ⚗️ STEP 2 — SCALING
# ==============================================================
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)
joblib.dump(scaler, scaler_path)
print(f"[INFO] Scaler saved at: {scaler_path}")

# Reshape for CNN-LSTM
X_scaled = X_scaled.reshape(X_scaled.shape[0], 1, X_scaled.shape[1])

X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.2, random_state=42
)

# ==============================================================
# ⚙️ STEP 3 — MODEL DEFINITION
# ==============================================================
def create_model(learning_rate=0.001, filters=64, dropout_rate=0.3):
    inputs = Input(shape=(X_train.shape[1], X_train.shape[2]))

    x = Conv1D(filters=filters, kernel_size=1, activation='relu')(inputs)
    x = Flatten()(x)

    lstm_out = LSTM(64, return_sequences=False)(inputs)

    merged = concatenate([x, lstm_out])
    merged = Dropout(dropout_rate)(merged)
    merged = Dense(64, activation='relu')(merged)
    outputs = Dense(1, activation='linear')(merged)

    model = Model(inputs=inputs, outputs=outputs)
    model.compile(optimizer=Adam(learning_rate=learning_rate), loss='mse', metrics=['mae'])
    return model

# ==============================================================
# 🧬 STEP 4 — HYBRID AIS + PSO OPTIMIZATION (SIMULATED SEARCH)
# ==============================================================
def hybrid_ais_pso_search():
    print("\n[INFO] Running Hybrid AIS + PSO Optimization...")
    best_params = None
    best_score = float('inf')

    # AIS exploration: wider random search
    learning_rates = np.random.choice([0.0005, 0.001, 0.002, 0.003], 3, replace=False)
    filters = np.random.choice([32, 64, 128], 3, replace=False)
    dropout_rates = np.random.choice([0.2, 0.3, 0.4], 3, replace=False)

    # PSO exploitation: fine-tune around best candidates
    for lr in learning_rates:
        for f in filters:
            for dr in dropout_rates:
                model = create_model(lr, f, dr)
                history = model.fit(
                    X_train, y_train,
                    validation_split=0.2,
                    epochs=15,
                    batch_size=16,
                    verbose=0
                )
                val_loss = min(history.history['val_loss'])
                if val_loss < best_score:
                    best_score = val_loss
                    best_params = {'learning_rate': lr, 'filters': f, 'dropout_rate': dr}
                    model.save(model_path)

    print(f"[INFO] Best Parameters (Hybrid AIS+PSO): {best_params}")
    return best_params

best_params = hybrid_ais_pso_search()

# ==============================================================
# 🧩 STEP 5 — FINAL MODEL TRAINING
# ==============================================================
print("\n[INFO] Training Final Model...")
model = create_model(**best_params)
early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

history = model.fit(
    X_train, y_train,
    validation_data=(X_test, y_test),
    epochs=100,
    batch_size=16,
    callbacks=[early_stop],
    verbose=1
)

model.save(model_path)
print(f"[INFO] Model saved at: {model_path}")

# ==============================================================
# 📊 STEP 6 — EVALUATION
# ==============================================================
y_pred = model.predict(X_test).flatten()
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
rmse = np.sqrt(mse)

metrics = {'MAE': mae, 'MSE': mse, 'RMSE': rmse, 'R2_Score': r2}
print("\n📊 MODEL PERFORMANCE METRICS:")
for k, v in metrics.items():
    print(f"{k}: {v:.4f}")

# ==============================================================
# 💾 STEP 7 — SAVE RESULTS
# ==============================================================
results_df = pd.DataFrame({'Actual_Yield': y_test, 'Predicted_Yield': y_pred})
results_df.to_csv(csv_path, index=False)
print(f"[INFO] Results CSV saved at: {csv_path}")

with open(json_path, "w") as f:
    json.dump({'metrics': metrics, 'best_params': best_params}, f, indent=4)

with open(yaml_path, "w") as f:
    yaml.dump({'optimizer': 'Hybrid AIS+PSO', 'best_params': best_params}, f)

print(f"[INFO] YAML & JSON configs saved.")

# ==============================================================
# 📈 STEP 8 — VISUALIZATIONS
# ==============================================================

# 1️⃣ Accuracy (Training Loss)
plt.figure(figsize=(8,6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title("Hybrid AIS+PSO SkyHarvest Accuracy Graph")
plt.xlabel("Epochs")
plt.ylabel("MSE Loss")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.savefig(os.path.join(base_path, "hybrid_skyharvest_accuracy_graph.png"))

# 2️⃣ Heatmap
plt.figure(figsize=(10,8))
sns.heatmap(df.corr(numeric_only=True), cmap='YlGnBu', annot=True, fmt=".2f")
plt.title("Hybrid AIS+PSO SkyHarvest Feature Correlation Heatmap")
plt.tight_layout()
plt.savefig(os.path.join(base_path, "hybrid_skyharvest_heatmap.png"))

# 3️⃣ Comparison (Actual vs Predicted)
plt.figure(figsize=(7,7))
plt.scatter(y_test, y_pred, color='green', alpha=0.6, edgecolors='black')
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--', lw=2)
plt.title("Hybrid AIS+PSO SkyHarvest Comparison Graph")
plt.xlabel("Actual Yield")
plt.ylabel("Predicted Yield")
plt.grid(True)
plt.tight_layout()
plt.savefig(os.path.join(base_path, "hybrid_skyharvest_comparison_graph.png"))

# 4️⃣ Result (Bar Chart)
plt.figure(figsize=(12,6))
sample_count = min(50, len(y_test))
bar_width = 0.35
indices = np.arange(sample_count)
plt.bar(indices, y_test[:sample_count], bar_width, label='Actual', color='skyblue')
plt.bar(indices + bar_width, y_pred[:sample_count], bar_width, label='Predicted', color='orange')
plt.title("Hybrid AIS+PSO SkyHarvest Result Graph (Top 50)")
plt.xlabel("Sample Index")
plt.ylabel("Yield Value")
plt.legend()
plt.tight_layout()
plt.savefig(os.path.join(base_path, "hybrid_skyharvest_result_graph.png"))

# 5️⃣ Prediction (Line Chart)
plt.figure(figsize=(10,6))
plt.plot(y_pred, color='purple', linewidth=2)
plt.title("Hybrid AIS+PSO SkyHarvest Prediction Graph")
plt.xlabel("Sample Index")
plt.ylabel("Predicted Yield")
plt.grid(True)
plt.tight_layout()
plt.savefig(os.path.join(base_path, "hybrid_skyharvest_prediction_graph.png"))

# ==============================================================
# 🖥️ STEP 9 — DISPLAY RESULTS ON SCREEN
# ==============================================================
print("\n🖥️ DISPLAYING SAMPLE RESULTS (Actual vs Predicted):\n")
print(results_df.head(10).to_string(index=False))

print("\n📈 Model Metrics Summary:")
for key, value in metrics.items():
    print(f"{key:<10} : {value:.4f}")

print("\n✅ HYBRID AIS+PSO SkyHarvest pipeline executed successfully!")
print(f"📁 All outputs saved under: {base_path}")
# Out:
# WARNING:tensorflow:From C:\Users\NXTWAVE\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
#
# [INFO] Loading dataset...
# [INFO] Dataset loaded: 2596 rows, 6 columns
# [INFO] Scaler saved at: C:\Users\NXTWAVE\Downloads\Drone Based Crop Yield Estimation & Disease Mapping System\hybrid_skyharvest_scaler.pkl
#
# [INFO] Running Hybrid AIS + PSO Optimization...
# WARNING:tensorflow:From C:\Users\NXTWAVE\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From C:\Users\NXTWAVE\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\NXTWAVE\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
# C:\Users\NXTWAVE\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# [INFO] Best Parameters (Hybrid AIS+PSO): {'learning_rate': 0.002, 'filters': 128, 'dropout_rate': 0.3}
#
# [INFO] Training Final Model...
# Epoch 1/100
# 130/130 [==============================] - 3s 7ms/step - loss: 9.4161 - mae: 1.9688 - val_loss: 0.9726 - val_mae: 0.7551
# Epoch 2/100
# 130/130 [==============================] - 0s 3ms/step - loss: 1.2011 - mae: 0.8628 - val_loss: 0.8443 - val_mae: 0.7066
# Epoch 3/100
# 130/130 [==============================] - 0s 4ms/step - loss: 1.0370 - mae: 0.8030 - val_loss: 0.6744 - val_mae: 0.6391
# Epoch 4/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.9094 - mae: 0.7457 - val_loss: 0.5845 - val_mae: 0.6069
# Epoch 5/100
# 130/130 [==============================] - 0s 4ms/step - loss: 0.7953 - mae: 0.6943 - val_loss: 0.5149 - val_mae: 0.5828
# Epoch 6/100
# 130/130 [==============================] - 0s 4ms/step - loss: 0.6991 - mae: 0.6499 - val_loss: 0.4688 - val_mae: 0.5353
# Epoch 7/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.6852 - mae: 0.6421 - val_loss: 0.4960 - val_mae: 0.5169
# Epoch 8/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.6582 - mae: 0.6328 - val_loss: 0.4842 - val_mae: 0.5131
# Epoch 9/100
# 130/130 [==============================] - 0s 4ms/step - loss: 0.6668 - mae: 0.6442 - val_loss: 0.4046 - val_mae: 0.4908
# Epoch 10/100
# 130/130 [==============================] - 0s 4ms/step - loss: 0.6019 - mae: 0.6075 - val_loss: 0.4080 - val_mae: 0.4831
# Epoch 11/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.5708 - mae: 0.5913 - val_loss: 0.4077 - val_mae: 0.5240
# Epoch 12/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.5959 - mae: 0.6026 - val_loss: 0.3995 - val_mae: 0.4863
# Epoch 13/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.5859 - mae: 0.5893 - val_loss: 0.4096 - val_mae: 0.4974
# Epoch 14/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.5687 - mae: 0.5958 - val_loss: 0.3735 - val_mae: 0.4651
# Epoch 15/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.5412 - mae: 0.5716 - val_loss: 0.3704 - val_mae: 0.4839
# Epoch 16/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.5551 - mae: 0.5823 - val_loss: 0.4030 - val_mae: 0.4790
# Epoch 17/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.5425 - mae: 0.5728 - val_loss: 0.3662 - val_mae: 0.4721
# Epoch 18/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.5180 - mae: 0.5635 - val_loss: 0.4026 - val_mae: 0.4794
# Epoch 19/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.5573 - mae: 0.5806 - val_loss: 0.3678 - val_mae: 0.4831
# Epoch 20/100
# 130/130 [==============================] - 0s 4ms/step - loss: 0.5377 - mae: 0.5726 - val_loss: 0.3613 - val_mae: 0.4691
# Epoch 21/100
# 130/130 [==============================] - 0s 4ms/step - loss: 0.5124 - mae: 0.5574 - val_loss: 0.3899 - val_mae: 0.4668
# Epoch 22/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.5079 - mae: 0.5491 - val_loss: 0.3519 - val_mae: 0.4683
# Epoch 23/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.5019 - mae: 0.5507 - val_loss: 0.3662 - val_mae: 0.4692
# Epoch 24/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.4877 - mae: 0.5418 - val_loss: 0.3424 - val_mae: 0.4583
# Epoch 25/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.5050 - mae: 0.5518 - val_loss: 0.3505 - val_mae: 0.4523
# Epoch 26/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.4742 - mae: 0.5341 - val_loss: 0.3395 - val_mae: 0.4665
# Epoch 27/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.4841 - mae: 0.5480 - val_loss: 0.3424 - val_mae: 0.4588
# Epoch 28/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.4630 - mae: 0.5298 - val_loss: 0.3642 - val_mae: 0.4925
# Epoch 29/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.4461 - mae: 0.5100 - val_loss: 0.3728 - val_mae: 0.4733
# Epoch 30/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.4330 - mae: 0.5094 - val_loss: 0.3256 - val_mae: 0.4314
# Epoch 31/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.4128 - mae: 0.4935 - val_loss: 0.3182 - val_mae: 0.4352
# Epoch 32/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.4161 - mae: 0.5000 - val_loss: 0.3104 - val_mae: 0.4310
# Epoch 33/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.4159 - mae: 0.5011 - val_loss: 0.3164 - val_mae: 0.4332
# Epoch 34/100
# 130/130 [==============================] - 1s 4ms/step - loss: 0.3937 - mae: 0.4818 - val_loss: 0.3123 - val_mae: 0.4460
# Epoch 35/100
# 130/130 [==============================] - 0s 4ms/step - loss: 0.3968 - mae: 0.4838 - val_loss: 0.3046 - val_mae: 0.4225
# Epoch 36/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.3836 - mae: 0.4727 - val_loss: 0.2854 - val_mae: 0.4199
# Epoch 37/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.3736 - mae: 0.4666 - val_loss: 0.4089 - val_mae: 0.4971
# Epoch 38/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.3878 - mae: 0.4782 - val_loss: 0.2879 - val_mae: 0.4069
# Epoch 39/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.3710 - mae: 0.4625 - val_loss: 0.2729 - val_mae: 0.4138
# Epoch 40/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.3417 - mae: 0.4456 - val_loss: 0.2416 - val_mae: 0.3705
# Epoch 41/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.3410 - mae: 0.4402 - val_loss: 0.2453 - val_mae: 0.3820
# Epoch 42/100
# 130/130 [==============================] - 0s 4ms/step - loss: 0.3122 - mae: 0.4198 - val_loss: 0.2437 - val_mae: 0.3804
# Epoch 43/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.3242 - mae: 0.4276 - val_loss: 0.2439 - val_mae: 0.3676
# Epoch 44/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.3048 - mae: 0.4155 - val_loss: 0.2171 - val_mae: 0.3535
# Epoch 45/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.2822 - mae: 0.3975 - val_loss: 0.2054 - val_mae: 0.3375
# Epoch 46/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.2626 - mae: 0.3821 - val_loss: 0.1923 - val_mae: 0.3215
# Epoch 47/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.2622 - mae: 0.3784 - val_loss: 0.1968 - val_mae: 0.3275
# Epoch 48/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.2773 - mae: 0.3884 - val_loss: 0.2105 - val_mae: 0.3481
# Epoch 49/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.2613 - mae: 0.3707 - val_loss: 0.1801 - val_mae: 0.3112
# Epoch 50/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.2532 - mae: 0.3664 - val_loss: 0.1867 - val_mae: 0.3090
# Epoch 51/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.2373 - mae: 0.3531 - val_loss: 0.2280 - val_mae: 0.3521
# Epoch 52/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.2726 - mae: 0.3815 - val_loss: 0.1939 - val_mae: 0.3169
# Epoch 53/100
# 130/130 [==============================] - 0s 4ms/step - loss: 0.2368 - mae: 0.3563 - val_loss: 0.1932 - val_mae: 0.3360
# Epoch 54/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.2531 - mae: 0.3655 - val_loss: 0.1893 - val_mae: 0.3180
# Epoch 55/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.2414 - mae: 0.3576 - val_loss: 0.2184 - val_mae: 0.3498
# Epoch 56/100
# 130/130 [==============================] - 0s 4ms/step - loss: 0.2393 - mae: 0.3598 - val_loss: 0.1989 - val_mae: 0.3241
# Epoch 57/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.2236 - mae: 0.3453 - val_loss: 0.1912 - val_mae: 0.3071
# Epoch 58/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.2285 - mae: 0.3446 - val_loss: 0.1767 - val_mae: 0.3055
# Epoch 59/100
# 130/130 [==============================] - 0s 4ms/step - loss: 0.2188 - mae: 0.3378 - val_loss: 0.1780 - val_mae: 0.3074
# Epoch 60/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.2207 - mae: 0.3369 - val_loss: 0.1682 - val_mae: 0.2886
# Epoch 61/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.2220 - mae: 0.3454 - val_loss: 0.1752 - val_mae: 0.3023
# Epoch 62/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.2159 - mae: 0.3406 - val_loss: 0.1661 - val_mae: 0.2931
# Epoch 63/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.2088 - mae: 0.3331 - val_loss: 0.1590 - val_mae: 0.2801
# Epoch 64/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.2144 - mae: 0.3296 - val_loss: 0.1591 - val_mae: 0.2811
# Epoch 65/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.2155 - mae: 0.3322 - val_loss: 0.2112 - val_mae: 0.3097
# Epoch 66/100
# 130/130 [==============================] - 0s 4ms/step - loss: 0.2183 - mae: 0.3407 - val_loss: 0.1681 - val_mae: 0.2953
# Epoch 67/100
# 130/130 [==============================] - 0s 4ms/step - loss: 0.2190 - mae: 0.3350 - val_loss: 0.1690 - val_mae: 0.2803
# Epoch 68/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.2088 - mae: 0.3342 - val_loss: 0.1958 - val_mae: 0.3103
# Epoch 69/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.2000 - mae: 0.3234 - val_loss: 0.1582 - val_mae: 0.2779
# Epoch 70/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.2103 - mae: 0.3324 - val_loss: 0.1947 - val_mae: 0.3025
# Epoch 71/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.2089 - mae: 0.3255 - val_loss: 0.1502 - val_mae: 0.2748
# Epoch 72/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.2075 - mae: 0.3242 - val_loss: 0.1473 - val_mae: 0.2661
# Epoch 73/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.2009 - mae: 0.3198 - val_loss: 0.1547 - val_mae: 0.2849
# Epoch 74/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.2049 - mae: 0.3229 - val_loss: 0.1609 - val_mae: 0.2854
# Epoch 75/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.2017 - mae: 0.3217 - val_loss: 0.1732 - val_mae: 0.2946
# Epoch 76/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.2021 - mae: 0.3223 - val_loss: 0.1596 - val_mae: 0.2901
# Epoch 77/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1834 - mae: 0.3017 - val_loss: 0.1523 - val_mae: 0.2613
# Epoch 78/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1880 - mae: 0.3080 - val_loss: 0.1418 - val_mae: 0.2604
# Epoch 79/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1951 - mae: 0.3149 - val_loss: 0.1477 - val_mae: 0.2671
# Epoch 80/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1952 - mae: 0.3181 - val_loss: 0.1499 - val_mae: 0.2747
# Epoch 81/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1912 - mae: 0.3152 - val_loss: 0.1416 - val_mae: 0.2685
# Epoch 82/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1829 - mae: 0.3125 - val_loss: 0.1401 - val_mae: 0.2621
# Epoch 83/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1885 - mae: 0.3094 - val_loss: 0.1409 - val_mae: 0.2470
# Epoch 84/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1756 - mae: 0.2976 - val_loss: 0.1349 - val_mae: 0.2521
# Epoch 85/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1878 - mae: 0.3086 - val_loss: 0.1371 - val_mae: 0.2602
# Epoch 86/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1773 - mae: 0.3025 - val_loss: 0.1470 - val_mae: 0.2816
# Epoch 87/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1782 - mae: 0.3020 - val_loss: 0.1599 - val_mae: 0.2679
# Epoch 88/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1862 - mae: 0.3057 - val_loss: 0.1417 - val_mae: 0.2711
# Epoch 89/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1799 - mae: 0.3070 - val_loss: 0.1455 - val_mae: 0.2678
# Epoch 90/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1831 - mae: 0.3042 - val_loss: 0.1335 - val_mae: 0.2605
# Epoch 91/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1682 - mae: 0.2909 - val_loss: 0.1309 - val_mae: 0.2528
# Epoch 92/100
# 130/130 [==============================] - 0s 4ms/step - loss: 0.1713 - mae: 0.2942 - val_loss: 0.1650 - val_mae: 0.2840
# Epoch 93/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1820 - mae: 0.3020 - val_loss: 0.1453 - val_mae: 0.2689
# Epoch 94/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1726 - mae: 0.3011 - val_loss: 0.1370 - val_mae: 0.2565
# Epoch 95/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1806 - mae: 0.3030 - val_loss: 0.1278 - val_mae: 0.2480
# Epoch 96/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1608 - mae: 0.2880 - val_loss: 0.1523 - val_mae: 0.2881
# Epoch 97/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1656 - mae: 0.2902 - val_loss: 0.1504 - val_mae: 0.2582
# Epoch 98/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1655 - mae: 0.2857 - val_loss: 0.1391 - val_mae: 0.2728
# Epoch 99/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1582 - mae: 0.2795 - val_loss: 0.1215 - val_mae: 0.2294
# Epoch 100/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.1660 - mae: 0.2938 - val_loss: 0.1365 - val_mae: 0.2740
# [INFO] Model saved at: C:\Users\NXTWAVE\Downloads\Drone Based Crop Yield Estimation & Disease Mapping System\hybrid_skyharvest_model.h5
# 17/17 [==============================] - 1s 2ms/step
#
# 📊 MODEL PERFORMANCE METRICS:
# MAE: 0.2740
# MSE: 0.1365
# RMSE: 0.3694
# R2_Score: 0.9637
# [INFO] Results CSV saved at: C:\Users\NXTWAVE\Downloads\Drone Based Crop Yield Estimation & Disease Mapping System\hybrid_skyharvest_result.csv
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 156
#     153 print(f"[INFO] Results CSV saved at: {csv_path}")
#     155 with open(json_path, "w") as f:
# --> 156     json.dump({'metrics': metrics, 'best_params': best_params}, f, indent=4)
#     158 with open(yaml_path, "w") as f:
#     159     yaml.dump({'optimizer': 'Hybrid AIS+PSO', 'best_params': best_params}, f)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\json\__init__.py:179, in dump(obj, fp, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     173     iterable = cls(skipkeys=skipkeys, ensure_ascii=ensure_ascii,
#     174         check_circular=check_circular, allow_nan=allow_nan, indent=indent,
#     175         separators=separators,
#     176         default=default, sort_keys=sort_keys, **kw).iterencode(obj)
#     177 # could accelerate with writelines in some versions of Python, at
#     178 # a debuggability cost
# --> 179 for chunk in iterable:
#     180     fp.write(chunk)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\json\encoder.py:432, in _make_iterencode.<locals>._iterencode(o, _current_indent_level)
#     430     yield from _iterencode_list(o, _current_indent_level)
#     431 elif isinstance(o, dict):
# --> 432     yield from _iterencode_dict(o, _current_indent_level)
#     433 else:
#     434     if markers is not None:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\json\encoder.py:406, in _make_iterencode.<locals>._iterencode_dict(dct, _current_indent_level)
#     404         else:
#     405             chunks = _iterencode(value, _current_indent_level)
# --> 406         yield from chunks
#     407 if newline_indent is not None:
#     408     _current_indent_level -= 1
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\json\encoder.py:406, in _make_iterencode.<locals>._iterencode_dict(dct, _current_indent_level)
#     404         else:
#     405             chunks = _iterencode(value, _current_indent_level)
# --> 406         yield from chunks
#     407 if newline_indent is not None:
#     408     _current_indent_level -= 1
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\json\encoder.py:439, in _make_iterencode.<locals>._iterencode(o, _current_indent_level)
#     437         raise ValueError("Circular reference detected")
#     438     markers[markerid] = o
# --> 439 o = _default(o)
#     440 yield from _iterencode(o, _current_indent_level)
#     441 if markers is not None:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\json\encoder.py:180, in JSONEncoder.default(self, o)
#     161 def default(self, o):
#     162     """Implement this method in a subclass such that it returns
#     163     a serializable object for ``o``, or calls the base implementation
#     164     (to raise a ``TypeError``).
#    (...)    178
#     179     """
# --> 180     raise TypeError(f'Object of type {o.__class__.__name__} '
#     181                     f'is not JSON serializable')
#
# TypeError: Object of type int32 is not JSON serializable
